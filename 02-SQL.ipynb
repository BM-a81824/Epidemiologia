# %% [markdown]
# # Utilização do ipython-SQL

# %% [markdown]
# ### Webografia
# * https://github.com/catherinedevlin/ipython-sql

# %% [markdown]
# ### Segundo ensaio
# Conectar à BD postgres.

# %%
# -*- coding: utf-8 -*-

# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Collecting ipython-sql',
#  '  Downloading ipython_sql-0.3.9-py2.py3-none-any.whl (21 kB)',
#  'Collecting sqlalchemy>=0.6.7',
#  '  Downloading SQLAlchemy-1.3.16-cp37-cp37m-win_amd64.whl (1.2 MB)',
#  'Requirement already satisfied: six in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (1.14.0)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Collecting sqlparse',
#  '  Downloading sqlparse-0.3.1-py2.py3-none-any.whl (40 kB)',
#  'Collecting prettytable',
#  '  Downloading prettytable-0.7.2.tar.bz2 (21 kB)',
#  'Requirement already satisfied: ipython>=1.0 in c:\\users\\barba\\appdata\\roaming\\python\\python37\\site-packages (from ipython-sql) (7.13.0)',
#  'Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\\users\\barba\\appdata\\roaming\\python\\python37\\site-packages (from ipython>=1.0->ipython-sql) (3.0.5)',
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
# %%sql
# CREATE TABLE writer (first_name, last_name, year_of_death);
# INSERT INTO writer VALUES('William', 'Shakespeare', 1616);
# INSERT INTO writer VALUES('Bertold', 'Brecht', 1956);
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %sql select * from Writer
# Out:
#  * sqlite://
# Done.
# [('William', 'Shakespeare', 1616), ('Bertold', 'Brecht', 1956)]

# %%
import os

user = os.getenv('postgres')
password = os.getenv('b1234')
connection_string = "postgresql://postgres:1234@localhost/miebiom".format(user=user, password=password)
# %sql $connection_string
# Out:
# 'Connected: postgres@miebiom'

# %%
# %sql select * from "braga-distrito" limit 10
# Out:
#  * postgresql://postgres:***@localhost/miebiom
#    sqlite://
# 10 rows affected.
# [(1, '0106000020B30E000001000000010300000001000000D104000000BE30992A31C7404039B4C82150084100F241CF265CC740003867C44E4E0841004A7B8337E5C740C0C64BB7434A08410 ... (39210 characters truncated) ... 1C640401FF4EC04550841005C6DC51ECEC640C0FA5CEDAE55084100F2D24D0AD0C64080C729BA915508410006A3926A14C74000371A405A51084100BE30992A31C7404039B4C821500841', '030521', 'Vale de Bouro', 'CELORICO DE BASTO', 'BRAGA', 'ÁREA PRINCIPAL', 789.11, 789.11, 'Vale de Bouro'),
#  (2, '0106000020B30E0000010000000103000000010000007E01000000787AA50C48C8C0C05D4B483455084100567DAE3652C8C080F085493E53084100643BDF0F5DC8C0C0EC9EBC574F08410 ... (11978 characters truncated) ... 2C8C0006D56FDD255084100363CBD1A58C8C0C035CD3BCB5508410008AC1C4A4EC8C0C037F8C27C55084100C6DCB50C4BC8C04082E2475855084100787AA50C48C8C0C05D4B4834550841', '030804', 'Azurém', 'GUIMARÃES', 'BRAGA', 'ÁREA PRINCIPAL', 290.01, 290.01, 'Azurém'),
# ...

# %%
# %sql select freguesia from "braga-distrito" limit 10
# Out:
#  * postgresql://postgres:***@localhost/miebiom
#    sqlite://
# 10 rows affected.
# [('Vale de Bouro',),
#  ('Azurém',),
#  ('Ribas',),
#  ('São Gens',),
#  ('União das freguesias de Refojos de Basto, Outeiro e Painzela',),
#  ('Sobreposta',),
#  ('União das freguesias de Lemenhe, Mouquim e Jesufrei',),
#  ('União das freguesias de Viatodos, Grimancelos, Minhotães e Monte de Fralães',),
#  ('Remelhe',),
#  ('Fermentões',)]

# %%
# %sql select * from "braga-distrito" where freguesia = 'Esporões'
# Out:
#  * postgresql://postgres:***@localhost/miebiom
#    sqlite://
# 1 rows affected.
# [(156, '0106000020B30E000001000000010300000001000000B80000000039D6C5A514D5C0400F0B35B713094100DC68006712D5C0C0F528DC8A05094100C58F314B17D5C0008C4AEA0F0009410 ... (5642 characters truncated) ... 9D5C080B3EAF3B616094100713D0A9B19D5C080A3013C46160941003867447518D5C00020D26FCF15094100492EFFD114D5C0006B2BF6CE1409410039D6C5A514D5C0400F0B35B7130941', '030313', 'Esporões', 'BRAGA', 'BRAGA', 'ÁREA PRINCIPAL', 474.07, 474.07, 'Esporões')]
